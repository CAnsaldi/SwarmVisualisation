# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook
# from IPython.display import HTML
import numpy as np
import pandas as pd
from matplotlib.animation import PillowWriter

#Initial Parameters
swarm_size = 50
world_size = 100
frames = 50
interval = 10
marker_size = 2
#Minimal Distance to keep between two instances
min_distance = 3
#Speed per interval
max_speed = 0.75
min_speed = 0.25

max_acceleration = 0.1
min_acceleration = 0.3

#Minimal movement Radius per axis
x_rad = 0.8
y_rad = 0.8
z_rad = 1


#Initialize random swarm
fig = plt.figure(figsize=[8,8])
ax = fig.add_subplot(projection='3d')

swarm = np.random.uniform(low=0, high=world_size, size=(3,swarm_size))

init_plot, = ax.plot(swarm[0], swarm[1], swarm[2], marker="o", markersize=marker_size, linestyle='None')

ax.set_xlim([0, world_size])
ax.set_ylim([0, world_size])
ax.set_zlim([0, world_size])

#Initialize Metadata



#Update Swarm
def update_point(x):
    swarm = np.random.uniform(low=0, high=world_size, size=(3,swarm_size))
    ax.clear()
    ax.set_xlim([0, world_size])
    ax.set_ylim([0, world_size])
    ax.set_zlim([0, world_size])
    init_plot, = ax.plot(swarm[0], swarm[1], swarm[2], marker="o", markersize=marker_size, linestyle='None')
    return swarm

#Run Animation
ani = FuncAnimation(fig, update_point, frames=frames, interval=interval)

plt.show()
ani.save('swarm.gif', writer='pillow')
# Out:
# <img src="data:image/png;base64,..." width="800">
