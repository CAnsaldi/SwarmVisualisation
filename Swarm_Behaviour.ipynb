# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook
# from IPython.display import HTML
import numpy as np
from matplotlib.animation import PillowWriter


swarm_size = 50
world_size = 100




fig = plt.figure()
ax = fig.add_subplot(projection='3d')

swarm = np.random.uniform(low=0, high=world_size, size=(3,swarm_size))

init_plot, = ax.plot(swarm[0], swarm[1], swarm[2], 'o')

ax.set_xlim([0, world_size])
ax.set_ylim([0, world_size])
ax.set_zlim([0, world_size])

def update_point(x):
    swarm = np.random.uniform(low=0, high=world_size, size=(3,swarm_size))
    ax.clear()
    ax.set_xlim([0, world_size])
    ax.set_ylim([0, world_size])
    ax.set_zlim([0, world_size])
    init_plot, = ax.plot(swarm[0], swarm[1], swarm[2], 'o')
    return swarm

ani = animation.FuncAnimation(fig, update_point, frames=999, interval=10)

plt.show()
ani.save('swarm.gif', writer='pillow')
# Out:
# <img src="data:image/png;base64,..." width="640">
